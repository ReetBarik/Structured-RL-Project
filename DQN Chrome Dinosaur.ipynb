# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
# Out:
# Using TensorFlow backend.

# %%
#path variables
game_url = "chrome://dino"
chrome_driver_path = "chromedriver.exe"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('runner-canvas')[0].id = 'runner-canvas'"

#get image from canvas
getbase64Script = "canvasRunner = document.getElementById('runner-canvas'); \
return canvasRunner.toDataURL().substring(22)"

# %%
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get('chrome://dino')
        self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return Runner.instance_.crashed")
    def get_playing(self):
        return self._driver.execute_script("return Runner.instance_.playing")
    def restart(self):
        self._driver.execute_script("Runner.instance_.restart()")
    def press_up(self):
        self._driver.find_element_by_tag_name("body").send_keys(Keys.ARROW_UP)
    def get_score(self):
        score_array = self._driver.execute_script("return Runner.instance_.distanceMeter.digits")
        score = ''.join(score_array) 
        return int(score)
    def pause(self):
        return self._driver.execute_script("return Runner.instance_.stop()")
    def resume(self):
        return self._driver.execute_script("return Runner.instance_.play()")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): 
        self._game = game; 
        self.jump(); 
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the experience

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen) #preprocessing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:300, :500] #Crop Region of Interest
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def buildmodel():
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    return model

# %%
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("Random Action")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            # saving model
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 812000 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9594793 / Loss  0.25773486495018005
# fps: 0.025804728485118195
# TIMESTEP 812001 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4953659 / Loss  0.05503523349761963
# fps: 2.776235977516369
# TIMESTEP 812002 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8288331 / Loss  0.3497477173805237
# fps: 3.0505049623478313
# TIMESTEP 812003 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8593819 / Loss  0.19813764095306396
# fps: 3.004765438961977
# TIMESTEP 812004 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.527616 / Loss  0.15354600548744202
# fps: 2.9428673265770633
# TIMESTEP 812005 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.0451388 / Loss  0.039291027933359146
# fps: 2.9768054535324824
# TIMESTEP 812006 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9244978 / Loss  0.03172535449266434
# fps: 2.8907574145241415
# TIMESTEP 812007 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7778784 / Loss  0.17707861959934235
# fps: 2.8425282978460973
# TIMESTEP 812008 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9594773 / Loss  0.022253558039665222
# fps: 3.032060596334321
# TIMESTEP 812009 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.996685 / Loss  0.021290075033903122
# fps: 2.858793082413017
# TIMESTEP 812010 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0413597 / Loss  0.2785419523715973
# fps: 2.802712433412005
# TIMESTEP 812011 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7184069 / Loss  0.028225626796483994
# fps: 2.810617386368891
# TIMESTEP 812012 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4115164 / Loss  0.007597646676003933
# fps: 2.850495096606702
# TIMESTEP 812013 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.97283 / Loss  0.04977462440729141
# fps: 2.900372443341728
# TIMESTEP 812014 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1753695 / Loss  0.011545104905962944
# fps: 2.8669690186093404
# TIMESTEP 812015 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8390083 / Loss  0.024660766124725342
# fps: 2.8185234937212766
# TIMESTEP 812016 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8596224 / Loss  0.08846516162157059
# fps: 3.0598807506304984
# TIMESTEP 812017 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6429822 / Loss  0.03788105025887489
# fps: 2.623858869895685
# TIMESTEP 812018 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  3.0584793 / Loss  0.012274131178855896
# fps: 3.0506425231945493
# TIMESTEP 812019 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8103869 / Loss  0.03798869252204895
# fps: 2.8587969794643655
# TIMESTEP 812020 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.565547 / Loss  0.1705211102962494
# fps: 2.493178435391295
# TIMESTEP 812021 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9314922 / Loss  0.015848884359002113
# fps: 2.9341754193524014
# TIMESTEP 812022 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7337371 / Loss  0.045828282833099365
# fps: 2.6071317351460515
# TIMESTEP 812023 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4792943 / Loss  0.026906780898571014
# fps: 2.8659268455839295
# TIMESTEP 812024 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6149273 / Loss  0.10696117579936981
# fps: 2.9690404054704533
# TIMESTEP 812025 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.7318621 / Loss  0.011772028170526028
# fps: 2.571826256724955
# TIMESTEP 812026 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8163474 / Loss  0.009796859696507454
# fps: 2.696701569940065
# TIMESTEP 812027 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0474143 / Loss  0.014585655182600021
# fps: 2.853710643555599
# TIMESTEP 812028 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.7822776 / Loss  0.46037814021110535
# fps: 2.464460055607915
# TIMESTEP 812029 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8924448 / Loss  0.04872261732816696
# fps: 2.6331063066298115
# TIMESTEP 812030 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.497426 / Loss  0.061714962124824524
# fps: 2.6897185042298752
# TIMESTEP 812031 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9321619 / Loss  0.04086655378341675
# fps: 2.433993589903547
# TIMESTEP 812032 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.001557 / Loss  0.11481831222772598
# fps: 2.7716696943124095
# TIMESTEP 812033 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8186635 / Loss  0.412846177816391
# fps: 0.8160991420489414
# TIMESTEP 812034 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8937434 / Loss  0.05220954865217209
# fps: 2.9690719314204004
# TIMESTEP 812035 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2664616 / Loss  0.07055530697107315
# fps: 2.8264818242896736
# TIMESTEP 812036 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.5977724 / Loss  0.11923836916685104
# fps: 2.9515485710586242
# TIMESTEP 812037 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7644832 / Loss  0.03922947496175766
# fps: 2.8588028250613093
# TIMESTEP 812038 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0544767 / Loss  0.05111641436815262
# fps: 2.5920301775974353
# TIMESTEP 812039 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.3954175 / Loss  0.10092182457447052
# fps: 2.8918396600093907
# TIMESTEP 812040 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.0310876 / Loss  0.0490468293428421
# fps: 2.689716779371355
# TIMESTEP 812041 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.978369 / Loss  0.06963661313056946
# fps: 2.6753329093763174
# TIMESTEP 812042 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  3.088675 / Loss  0.010451662354171276
# fps: 2.8185159176816463
# TIMESTEP 812043 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8206325 / Loss  0.2550959289073944
# fps: 2.925665306942406
# TIMESTEP 812044 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.0767138 / Loss  0.013547449372708797
# fps: 2.7115919589088477
# TIMESTEP 812045 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4661932 / Loss  0.056235723197460175
# fps: 2.866747591395733
# TIMESTEP 812046 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  3.0140007 / Loss  0.015384437516331673
# fps: 2.38247344620766
# TIMESTEP 812047 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7192187 / Loss  0.351926326751709
# fps: 2.6825055625658347
# TIMESTEP 812048 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8855528 / Loss  0.012480286881327629
# fps: 2.3654322268755434
# TIMESTEP 812049 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.0131605 / Loss  0.040336724370718
# fps: 2.6400390752853857
# TIMESTEP 812050 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.8249233 / Loss  0.03788190335035324
# fps: 2.9002180191854117
# TIMESTEP 812051 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9951373 / Loss  0.26692789793014526
# fps: 2.8106155029658755
# TIMESTEP 812052 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8697433 / Loss  0.026375949382781982
# fps: 2.8752194475235076
# TIMESTEP 812053 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.80956054 / Loss  0.043584149330854416
# fps: 2.9342164726754283
# TIMESTEP 812054 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.564986 / Loss  0.013957003131508827
# fps: 2.794917004844438
# TIMESTEP 812055 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9242119 / Loss  0.09152651578187943
# fps: 2.9779002426024705
# TIMESTEP 812056 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1043863 / Loss  0.3109229803085327
# fps: 3.0559168944109336
# TIMESTEP 812057 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.722365 / Loss  0.027500947937369347
# fps: 3.2383546582911005
# TIMESTEP 812058 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5497608 / Loss  0.007662787567824125
# fps: 2.9740340407910897
# TIMESTEP 812059 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0390916 / Loss  0.024261653423309326
# fps: 3.23308515255063
# TIMESTEP 812060 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1430428 / Loss  0.31174543499946594
# fps: 2.9937096683247217
# TIMESTEP 812061 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.7535534 / Loss  0.29307055473327637
# fps: 2.9789048595101426
# TIMESTEP 812062 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.177036 / Loss  0.30320778489112854
# fps: 3.0033647563433785
# TIMESTEP 812063 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.692234 / Loss  0.17524658143520355
# fps: 2.980234109767553
# TIMESTEP 812064 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8910911 / Loss  0.20109066367149353
# fps: 3.152737323253924
# TIMESTEP 812065 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.892387 / Loss  0.03697403520345688
# fps: 2.8901717853131483
# TIMESTEP 812066 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9037881 / Loss  0.011423327960073948
# fps: 2.9079412796510167
# TIMESTEP 812067 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9149625 / Loss  0.2818039655685425
# fps: 0.8800532777615283
# TIMESTEP 812068 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8007412 / Loss  0.06691524386405945
# fps: 2.975916266027915
# TIMESTEP 812069 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8890972 / Loss  0.25877997279167175
# fps: 3.01011120241423
# TIMESTEP 812070 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7482322 / Loss  0.03394433856010437
# fps: 2.878453516413682
# TIMESTEP 812071 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.718658 / Loss  0.017862364649772644
# fps: 2.9256571439731927
# TIMESTEP 812072 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6610112 / Loss  0.05729762092232704
# fps: 2.633107959646182
# TIMESTEP 812073 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8750858 / Loss  0.1660732477903366
# fps: 2.8746420665218255
# TIMESTEP 812074 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9556041 / Loss  0.040065862238407135
# fps: 2.9794910227494715
# TIMESTEP 812075 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.508714 / Loss  0.1910494565963745
# fps: 2.9779129282747037
# TIMESTEP 812076 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6849912 / Loss  0.01802043616771698
# fps: 2.9781243720582147
# TIMESTEP 812077 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8109196 / Loss  0.019877677783370018
# fps: 3.0301877005258735
# TIMESTEP 812078 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8052654 / Loss  0.02068987302482128
# fps: 3.024199049111913
# TIMESTEP 812079 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.686029 / Loss  0.018579304218292236
# fps: 2.997652937830011
# TIMESTEP 812080 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.622739 / Loss  0.025746408849954605
# fps: 3.1358719544471727
# TIMESTEP 812081 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9582419 / Loss  0.05157642811536789
# fps: 2.9568920058315777
# TIMESTEP 812082 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.441352 / Loss  0.0627768263220787
# fps: 3.0354376495807216
# TIMESTEP 812083 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6903129 / Loss  0.01356720831245184
# fps: 2.989518910508388
# TIMESTEP 812084 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.14239 / Loss  0.020820531994104385
# fps: 3.008092717701565
# TIMESTEP 812085 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.1006528 / Loss  0.4691591262817383
# fps: 2.752610491844161
# TIMESTEP 812086 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7805815 / Loss  0.03387829288840294
# fps: 2.682347734718793
# TIMESTEP 812087 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.024662 / Loss  0.010955492965877056
# fps: 2.8155964953264756
# TIMESTEP 812088 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8518984 / Loss  0.08999685943126678
# fps: 2.8999172401204962
# TIMESTEP 812089 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.7856946 / Loss  0.06738387793302536
# fps: 2.8829070573865874
# TIMESTEP 812090 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6644793 / Loss  0.2705691456794739
# fps: 2.858520315218643
# TIMESTEP 812091 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.1872785 / Loss  0.35396644473075867
# fps: 2.8514989339946917
# TIMESTEP 812092 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8332369 / Loss  0.07202211022377014
# fps: 2.8553891734540215
# TIMESTEP 812093 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7903951 / Loss  0.041734665632247925
# fps: 2.85063652125215
# TIMESTEP 812094 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8388785 / Loss  0.23182767629623413
# fps: 2.86793742961447
# TIMESTEP 812095 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.650564 / Loss  0.010699882172048092
# fps: 2.8491300050606774
# TIMESTEP 812096 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.646849 / Loss  0.13676975667476654
# fps: 2.85335343370822
# TIMESTEP 812097 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.3467097 / Loss  0.1705719530582428
# fps: 2.866673136831688
# TIMESTEP 812098 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.7034714 / Loss  0.017206445336341858
# fps: 2.7162841542794567
# TIMESTEP 812099 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4268727 / Loss  0.04299609363079071
# fps: 2.612272555998792
# TIMESTEP 812100 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9131513 / Loss  0.11853791028261185
# fps: 2.7042561545737236
# TIMESTEP 812101 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8714685 / Loss  0.39432334899902344
# fps: 2.381997177475459
# TIMESTEP 812102 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  2.737278 / Loss  0.025919049978256226
# fps: 0.7633499205219959
# TIMESTEP 812103 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8573389 / Loss  0.28717508912086487
# fps: 3.0010224487970665
# TIMESTEP 812104 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5932302 / Loss  0.06953591108322144
# fps: 2.7254889474292976
# TIMESTEP 812105 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8050704 / Loss  0.2564595937728882
# fps: 2.616961724249378
# TIMESTEP 812106 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7982416 / Loss  0.021975591778755188
# fps: 2.8481529769665364
# TIMESTEP 812107 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6980917 / Loss  0.06687001883983612
# fps: 2.7412318310153716
# TIMESTEP 812108 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6660724 / Loss  0.21480512619018555
# fps: 2.7260115050925404
# TIMESTEP 812109 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2279315 / Loss  0.2072352021932602
# fps: 2.861925839597749
# TIMESTEP 812110 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8395418 / Loss  0.010055672377347946
# fps: 3.158311502604251
# TIMESTEP 812111 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.725108 / Loss  0.11898380517959595
# fps: 3.168638045226499
# TIMESTEP 812112 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7160387 / Loss  0.17288218438625336
# fps: 2.9818379843269347
# TIMESTEP 812113 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.7210503 / Loss  0.0928344577550888
# fps: 3.1960424980359554
# TIMESTEP 812114 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5644164 / Loss  0.019134439527988434
# fps: 2.966600228314055
# TIMESTEP 812115 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6081864 / Loss  0.030830018222332
# fps: 3.156386327531492
# TIMESTEP 812116 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5356433 / Loss  0.014747142791748047
# fps: 3.1429213712155044
# TIMESTEP 812117 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.590996 / Loss  0.06135641038417816
# fps: 3.1865436408598637
# TIMESTEP 812118 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6073724 / Loss  0.21080154180526733
# fps: 3.1369273503186808
# TIMESTEP 812119 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7694585 / Loss  0.40267664194107056
# fps: 3.116863506284179
# TIMESTEP 812120 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.636504 / Loss  0.013987356796860695
# fps: 3.0769226254796798
# TIMESTEP 812121 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2462173 / Loss  0.017611971125006676
# fps: 3.125335964167796
# TIMESTEP 812122 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0877836 / Loss  0.028282267972826958
# fps: 3.0938221719653938
# TIMESTEP 812123 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5850766 / Loss  0.030333172529935837
# fps: 3.067765345394809
# TIMESTEP 812124 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5579886 / Loss  0.06484880298376083
# fps: 3.1263912699950804
# TIMESTEP 812125 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3691716 / Loss  0.01098976843059063
# fps: 3.1242720616168462
# TIMESTEP 812126 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6101248 / Loss  0.017698680981993675
# fps: 2.9348139285102035
# TIMESTEP 812127 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4861226 / Loss  0.016939114779233932
# fps: 2.945063864775615
# TIMESTEP 812128 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.40536 / Loss  0.24943280220031738
# fps: 3.133472987147267
# TIMESTEP 812129 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3991196 / Loss  0.02381085976958275
# fps: 3.095566663886714
# TIMESTEP 812130 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5766569 / Loss  0.0034937341697514057
# fps: 3.0532518706545817
# TIMESTEP 812131 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5310167 / Loss  0.019559478387236595
# fps: 2.950894455830197
# TIMESTEP 812132 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.487874 / Loss  0.012636743485927582
# fps: 2.9545862153254
# TIMESTEP 812133 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.3459961 / Loss  0.011686166748404503
# fps: 3.206764758726409
# TIMESTEP 812134 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3921344 / Loss  0.21341386437416077
# fps: 2.968874379848226
# TIMESTEP 812135 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6636398 / Loss  0.236921027302742
# fps: 3.034600914510621
# TIMESTEP 812136 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2498176 / Loss  0.2219858318567276
# fps: 0.8380000063934326
# TIMESTEP 812137 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.3122382 / Loss  0.21708133816719055
# fps: 3.097473238781335
# TIMESTEP 812138 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5083965 / Loss  0.02033831924200058
# fps: 3.107384429828136
# TIMESTEP 812139 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4989002 / Loss  0.0465584322810173
# fps: 3.0692447234257725
# TIMESTEP 812140 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6279742 / Loss  0.015383513644337654
# fps: 3.164779179465588
# TIMESTEP 812141 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5528715 / Loss  0.02492392435669899
# fps: 3.1325696412220467
# TIMESTEP 812142 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6961399 / Loss  0.05126876011490822
# fps: 3.1126814393290037
# TIMESTEP 812143 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6873546 / Loss  0.018358871340751648
# fps: 3.0872387188519896
# TIMESTEP 812144 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7595423 / Loss  0.035380441695451736
# fps: 3.107384429828136
# TIMESTEP 812145 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.173709 / Loss  0.03694336116313934
# fps: 3.1349063034405233
# TIMESTEP 812146 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6739398 / Loss  0.01364994142204523
# fps: 3.16790332326284
# TIMESTEP 812147 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5539265 / Loss  0.026965979486703873
# fps: 3.1170580790533866
# TIMESTEP 812148 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7365229 / Loss  0.15826864540576935
# fps: 3.0045674137664258
# TIMESTEP 812149 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.550831 / Loss  0.013119958341121674
# fps: 3.039828726691081
# TIMESTEP 812150 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.360729 / Loss  0.2372557371854782
# fps: 2.9303440494363655
# TIMESTEP 812151 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6658282 / Loss  0.06588796526193619
# fps: 3.0736171007939967
# TIMESTEP 812152 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5598799 / Loss  0.015894392505288124
# fps: 3.1269017065502873
# TIMESTEP 812153 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4062278 / Loss  0.20610886812210083
# fps: 2.9292246148774828
# TIMESTEP 812154 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5471058 / Loss  0.017699109390378
# fps: 2.903369921634076
# TIMESTEP 812155 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5411384 / Loss  0.013441994786262512
# fps: 2.8730825242385922
# TIMESTEP 812156 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4224486 / Loss  0.009255921468138695
# fps: 2.9094016667152225
# TIMESTEP 812157 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9205381 / Loss  0.012769592925906181
# fps: 3.0883321196395292
# TIMESTEP 812158 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6934173 / Loss  0.2551015615463257
# fps: 2.995492802839584
# TIMESTEP 812159 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.697614 / Loss  0.027252018451690674
# fps: 2.8199409294104436
# TIMESTEP 812160 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.7323956 / Loss  0.03943590074777603
# fps: 2.572165349912397
# TIMESTEP 812161 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0240498 / Loss  0.019757887348532677
# fps: 2.5267058998583725
# TIMESTEP 812162 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -1.3347332 / Loss  0.33226874470710754
# fps: 2.654201136401749
# TIMESTEP 812163 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.721089 / Loss  0.34503552317619324
# fps: 2.771684346933691
# TIMESTEP 812164 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5847409 / Loss  0.07539083063602448
# fps: 2.8752056507337618
# TIMESTEP 812165 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6615194 / Loss  0.02934158965945244
# fps: 2.5596937866319704
# TIMESTEP 812166 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.394888 / Loss  0.022133642807602882
# fps: 2.867553123485226
# TIMESTEP 812167 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5952554 / Loss  0.011310934089124203
# fps: 2.718957095581205
# TIMESTEP 812168 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7214267 / Loss  0.14386910200119019
# fps: 2.91349613645899
# TIMESTEP 812169 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8360057 / Loss  0.2504647374153137
# fps: 2.8791332199336352
# TIMESTEP 812170 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6726991 / Loss  0.031140930950641632
# fps: 0.8893118149890551
# TIMESTEP 812171 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  2.6263769 / Loss  0.2684178054332733
# fps: 2.8425494885611604
# TIMESTEP 812172 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.755908 / Loss  0.007325988262891769
# fps: 2.7715707931708264
# TIMESTEP 812173 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7163892 / Loss  0.032904379069805145
# fps: 2.640127149983477
# TIMESTEP 812174 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7949278 / Loss  0.2731356620788574
# fps: 2.858785288342195
# TIMESTEP 812175 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6428959 / Loss  0.25868847966194153
# fps: 2.598909082572275
# TIMESTEP 812176 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6780274 / Loss  0.09439773112535477
# fps: 2.6681917218258677
# TIMESTEP 812177 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.557024 / Loss  0.02729630470275879
# fps: 2.771645884133246
# TIMESTEP 812178 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5630193 / Loss  0.020228758454322815
# fps: 2.9263919936815723
# TIMESTEP 812179 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.487292 / Loss  0.04293963313102722
# fps: 2.8664164941633627
# TIMESTEP 812180 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5515356 / Loss  0.010517353191971779
# fps: 3.0994577450529768
# TIMESTEP 812181 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6100595 / Loss  0.2872111201286316
# fps: 2.934214419981993
# TIMESTEP 812182 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2846687 / Loss  0.03674881160259247
# fps: 3.0650281086698055
# TIMESTEP 812183 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8419756 / Loss  0.2622787654399872
# fps: 2.925457165455603
# TIMESTEP 812184 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8865075 / Loss  0.01797243021428585
# fps: 2.9002079922113553
# TIMESTEP 812185 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6901393 / Loss  0.009939076378941536
# fps: 3.0602044657944427
# TIMESTEP 812186 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.99213976 / Loss  0.15822537243366241
# fps: 2.8687004648134318
# TIMESTEP 812187 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6067822 / Loss  0.21047094464302063
# fps: 2.8804836993883023
# TIMESTEP 812188 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4888945 / Loss  0.009735392406582832
# fps: 2.860772202457603
# TIMESTEP 812189 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.7818482 / Loss  0.23518279194831848
# fps: 2.9254285993276326
# TIMESTEP 812190 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1971729 / Loss  0.015917306765913963
# fps: 2.9689269175938287
# TIMESTEP 812191 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.744464 / Loss  0.045959826558828354
# fps: 2.9082517916971753
# TIMESTEP 812192 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6119299 / Loss  0.03845733404159546
# fps: 2.908639016488028
# TIMESTEP 812193 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7739136 / Loss  0.021699029952287674
# fps: 2.6333360958128345
# TIMESTEP 812194 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.662072 / Loss  0.22119607031345367
# fps: 2.8213540979989613
# TIMESTEP 812195 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5211085 / Loss  0.21228834986686707
# fps: 3.0828207308710285
# TIMESTEP 812196 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3856206 / Loss  0.017202310264110565
# fps: 2.8625489171012957
# TIMESTEP 812197 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6806927 / Loss  0.059159137308597565
# fps: 3.097523563917426
# TIMESTEP 812198 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.408837 / Loss  0.018380243331193924
# fps: 2.9517812152518754
# TIMESTEP 812199 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8052044 / Loss  0.02378784865140915
# fps: 2.95839989955994
# TIMESTEP 812200 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6230798 / Loss  0.01823575422167778
# fps: 2.9395755655854896
# TIMESTEP 812201 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2746093 / Loss  0.07575678825378418
# fps: 2.891255585288615
# TIMESTEP 812202 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5314577 / Loss  0.39673781394958496
# fps: 2.905449505021824
# TIMESTEP 812203 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4877152 / Loss  0.17946287989616394
# fps: 2.5142994161301537
# TIMESTEP 812204 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4502463 / Loss  0.03413628414273262
# fps: 0.8692740926806167
# TIMESTEP 812205 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7456704 / Loss  0.012624895200133324
# fps: 2.8699822572136093
# TIMESTEP 812206 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.040813595 / Loss  0.07315545529127121
# fps: 2.8587015047648388
# TIMESTEP 812207 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5215442 / Loss  0.12955354154109955
# fps: 2.716224346200897
# TIMESTEP 812208 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3218355 / Loss  0.08433562517166138
# fps: 2.6050720069463553
# TIMESTEP 812209 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.1591973 / Loss  0.21691198647022247
# fps: 2.8743071735972148
# TIMESTEP 812210 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5791647 / Loss  0.009065707214176655
# fps: 3.022287938169364
# TIMESTEP 812211 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -1.0263569 / Loss  0.4288831353187561
# fps: 2.9933015993091785
# TIMESTEP 812212 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6244072 / Loss  0.01933760941028595
# fps: 2.99377804679063
# TIMESTEP 812213 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5399306 / Loss  0.030839435756206512
# fps: 3.0096036279096468
# TIMESTEP 812214 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6554835 / Loss  0.021074756979942322
# fps: 3.001406852214683
# TIMESTEP 812215 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1320028 / Loss  0.011809101328253746
# fps: 2.9958436931489865
# TIMESTEP 812216 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.326016 / Loss  0.004744294099509716
# fps: 3.0039627375189526
# TIMESTEP 812217 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8823352 / Loss  0.18964526057243347
# fps: 2.8605634369558826
# TIMESTEP 812218 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4897505 / Loss  0.03244279697537422
# fps: 3.0044877805579175
# TIMESTEP 812219 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6995095 / Loss  0.04351494461297989
# fps: 2.9901113903295373
# TIMESTEP 812220 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4083936 / Loss  0.011025942862033844
# fps: 2.995668237719115
# TIMESTEP 812221 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7101063 / Loss  0.015984784811735153
# fps: 2.859414796433149
# TIMESTEP 812222 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6672962 / Loss  0.2034303843975067
# fps: 2.95141149433052
# TIMESTEP 812223 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.24395251 / Loss  0.4317483901977539
# fps: 2.539446048553547
# TIMESTEP 812224 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.9722375 / Loss  0.19662261009216309
# fps: 2.849976014100719
# TIMESTEP 812225 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6771845 / Loss  0.18755866587162018
# fps: 2.8669709782948978
# TIMESTEP 812226 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.66484 / Loss  0.2853996157646179
# fps: 2.7338080541768375
# TIMESTEP 812227 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4425061 / Loss  0.253629595041275
# fps: 2.612445025222531
# TIMESTEP 812228 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.674248 / Loss  0.03326530009508133
# fps: 2.500931073157963
# TIMESTEP 812229 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.3721943 / Loss  0.048812657594680786
# fps: 2.9805263651583673
# TIMESTEP 812230 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6121058 / Loss  0.012771734036505222
# fps: 2.874900184312024
# TIMESTEP 812231 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6539682 / Loss  0.023352332413196564
# fps: 2.7246975213805693
# TIMESTEP 812232 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8554575 / Loss  0.1856054663658142
# fps: 3.01327930801615
# TIMESTEP 812233 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4961827 / Loss  0.09286138415336609
# fps: 2.8918217156346997
# TIMESTEP 812234 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.6069174 / Loss  0.07834492623806
# fps: 3.0320584044605763
# TIMESTEP 812235 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5937433 / Loss  0.040459077805280685
# fps: 3.077947743258763
# TIMESTEP 812236 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.320364 / Loss  0.1789461225271225
# fps: 2.7640038643166207
# TIMESTEP 812237 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7893214 / Loss  0.008306117728352547
# fps: 2.7435018255981434
# TIMESTEP 812238 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5944006 / Loss  0.16727256774902344
# fps: 0.8637531286643523
# TIMESTEP 812239 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6155415 / Loss  0.011991331353783607
# fps: 2.9866174487277535
# TIMESTEP 812240 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6954532 / Loss  0.030126791447401047
# fps: 2.95162542267323
# TIMESTEP 812241 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7431386 / Loss  0.04599785804748535
# fps: 2.7412855789026502
# TIMESTEP 812242 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.398032 / Loss  0.050050318241119385
# fps: 2.80275176328688
# TIMESTEP 812243 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2489166 / Loss  0.020249269902706146
# fps: 2.704160262427662
# TIMESTEP 812244 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8021182 / Loss  0.017736323177814484
# fps: 2.4706413188050833
# TIMESTEP 812245 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.7157135 / Loss  0.07312697917222977
# fps: 2.6400440604887567
# TIMESTEP 812246 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.577126 / Loss  0.008050041273236275
# fps: 3.004705167660999
# TIMESTEP 812247 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5943208 / Loss  0.11862534284591675
# fps: 2.992379047159729
# TIMESTEP 812248 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6420285 / Loss  0.01456859614700079
# fps: 3.013781626605581
# TIMESTEP 812249 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7815465 / Loss  0.1837894171476364
# fps: 2.850646208385213
# TIMESTEP 812250 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7560658 / Loss  0.028464816510677338
# fps: 2.733462415009101
# TIMESTEP 812251 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6392679 / Loss  0.05530507117509842
# fps: 3.004330678769073
# TIMESTEP 812252 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6353114 / Loss  0.2599071264266968
# fps: 2.982677687219861
# TIMESTEP 812253 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2067735 / Loss  0.17587198317050934
# fps: 3.002655231536333
# TIMESTEP 812254 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.465022 / Loss  0.040108680725097656
# fps: 2.8669846961688132
# TIMESTEP 812255 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3739333 / Loss  0.0685451328754425
# fps: 2.9953195275822226
# TIMESTEP 812256 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2748313 / Loss  0.00761529291048646
# fps: 2.9931307134038865
# TIMESTEP 812257 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6019037 / Loss  0.22248104214668274
# fps: 2.8537572427382107
# TIMESTEP 812258 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8809184 / Loss  0.01362250093370676
# fps: 2.891718041385663
# TIMESTEP 812259 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.512343 / Loss  0.27595993876457214
# fps: 2.9481130351414344
# TIMESTEP 812260 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5802424 / Loss  0.04171736538410187
# fps: 3.0784357043301216
# TIMESTEP 812261 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.41865 / Loss  0.03350424766540527
# fps: 2.9757536929945734
# TIMESTEP 812262 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6889845 / Loss  0.1663350760936737
# fps: 3.127260743494479
# TIMESTEP 812263 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4934354 / Loss  0.01370550412684679
# fps: 2.8678060480750034
# TIMESTEP 812264 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7556539 / Loss  0.27071207761764526
# fps: 3.022958839856056
# TIMESTEP 812265 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.503481 / Loss  0.22163262963294983
# fps: 2.9515734954681077
# TIMESTEP 812266 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6914731 / Loss  0.01751779019832611
# fps: 3.146469780250694
# TIMESTEP 812267 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6301539 / Loss  0.13693875074386597
# fps: 3.065928772394314
# TIMESTEP 812268 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.718986 / Loss  0.006659995298832655
# fps: 2.925383710825088
# TIMESTEP 812269 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.417696 / Loss  0.10566301643848419
# fps: 3.1351804691068073
# TIMESTEP 812270 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.61327 / Loss  0.06128326803445816
# fps: 2.995732426345964
# TIMESTEP 812271 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5037704 / Loss  0.23852474987506866
# fps: 2.9691118652514503
# TIMESTEP 812272 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6815981 / Loss  0.048778243362903595
# fps: 0.8090342944725397
# TIMESTEP 812273 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7318842 / Loss  0.039945557713508606
# fps: 3.010100401174098
# TIMESTEP 812274 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4054775 / Loss  0.027772463858127594
# fps: 2.8501967947463416
# TIMESTEP 812275 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5178981 / Loss  0.057151101529598236
# fps: 2.716210274094581
# TIMESTEP 812276 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4969745 / Loss  0.23241540789604187
# fps: 2.612715164298222
# TIMESTEP 812277 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4923272 / Loss  0.00720209302380681
# fps: 2.605638431437352
# TIMESTEP 812278 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.490281 / Loss  0.14850656688213348
# fps: 2.7480189032176483
# TIMESTEP 812279 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6273441 / Loss  0.5506099462509155
# fps: 2.71810075944478
# TIMESTEP 812280 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3285525 / Loss  0.13729983568191528
# fps: 3.0131710716312616
# TIMESTEP 812281 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7357652 / Loss  0.01399063691496849
# fps: 2.997068173714459
# TIMESTEP 812282 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6894679 / Loss  0.14441314339637756
# fps: 2.9934041402187583
# TIMESTEP 812283 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7113941 / Loss  0.19862677156925201
# fps: 2.8264589677635867
# TIMESTEP 812284 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5524566 / Loss  0.11374091356992722
# fps: 3.0319619651530365
# TIMESTEP 812285 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6173055 / Loss  0.032013677060604095
# fps: 2.7312232245242685
# TIMESTEP 812286 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5272367 / Loss  0.04431748390197754
# fps: 2.866986655875803
# TIMESTEP 812287 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6223637 / Loss  0.08741264790296555
# fps: 2.853957248178982
# TIMESTEP 812288 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5655172 / Loss  0.1362776905298233
# fps: 2.6970466457511733
# TIMESTEP 812289 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7712127 / Loss  0.03882157802581787
# fps: 2.4168115841818065
# TIMESTEP 812290 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6297175 / Loss  0.09515315294265747
# fps: 2.576156007677543
# TIMESTEP 812291 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.3755856 / Loss  0.2128152847290039
# fps: 3.0320496369972885
# TIMESTEP 812292 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  -0.78626806 / Loss  0.208311066031456
# fps: 2.6455008300492984
# TIMESTEP 812293 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2250981 / Loss  0.006284344010055065
# fps: 3.0455765009486786
# TIMESTEP 812294 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6313 / Loss  0.03212309628725052
# fps: 2.9291386973051643
# TIMESTEP 812295 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.281542 / Loss  0.33802327513694763
# fps: 2.4941361721055193
# TIMESTEP 812296 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2858262 / Loss  0.1481734961271286
# fps: 2.565750387832104
# TIMESTEP 812297 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9302294 / Loss  0.05982552468776703
# fps: 2.7637270315611357
# TIMESTEP 812298 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.3778815 / Loss  0.2417047917842865
# fps: 2.594478503699369
# TIMESTEP 812299 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6025627 / Loss  0.052240729331970215
# fps: 2.607313250892508
# TIMESTEP 812300 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5886571 / Loss  0.06815188378095627
# fps: 2.684181054536635
# TIMESTEP 812301 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2741601 / Loss  0.15404586493968964
# fps: 2.6746368554059905
# TIMESTEP 812302 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5026308 / Loss  0.04747312515974045
# fps: 2.8751997378644036
# TIMESTEP 812303 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6503665 / Loss  0.013145743869245052
# fps: 2.519868812905792
# TIMESTEP 812304 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.5313838 / Loss  0.3921949863433838
# fps: 2.82427977331983
# TIMESTEP 812305 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.3296752 / Loss  0.0324971042573452
# fps: 2.709721017163553
# ...
# fps: 1.3969344274416104
# TIMESTEP 812699 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7432115 / Loss  0.041425734758377075
# fps: 1.3629331158344191
# TIMESTEP 812700 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.06362903 / Loss  0.20578579604625702
# fps: 0.7138516671330023
# TIMESTEP 812701 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5645049 / Loss  0.010734301060438156
# fps: 1.9176810268954245
# TIMESTEP 812702 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  1.498997 / Loss  0.03163932263851166
# fps: 1.9471123872216665
# TIMESTEP 812703 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.4815307 / Loss  0.04139608517289162
# fps: 1.7732861167764216
# TIMESTEP 812704 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.595604 / Loss  0.21289263665676117
# fps: 2.0700580452744255
# TIMESTEP 812705 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4778037 / Loss  0.054240189492702484
# fps: 1.8159180480252566
# TIMESTEP 812706 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6979759 / Loss  0.07501466572284698
# fps: 1.0909169410450767
# TIMESTEP 812707 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4664595 / Loss  0.01733022928237915
# fps: 1.4604788728176668
# TIMESTEP 812708 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7334597 / Loss  0.2268369495868683
# fps: 1.4661917677586336
# TIMESTEP 812709 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7341899 / Loss  0.11839249730110168
# fps: 2.056029356833964
# TIMESTEP 812710 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.6026034 / Loss  0.02757341042160988
# fps: 1.9530373722981216
# TIMESTEP 812711 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6666989 / Loss  0.38426637649536133
# fps: 1.934037233743322
# TIMESTEP 812712 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7769922 / Loss  0.19644300639629364
# fps: 0.7686101405937843
# TIMESTEP 812713 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8765709 / Loss  0.027167562395334244
# fps: 1.4300398431911647
# TIMESTEP 812714 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7910666 / Loss  0.014218982309103012
# fps: 0.6894168702249549
# TIMESTEP 812715 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4798791 / Loss  0.2120175063610077
# fps: 0.45957173954799346
# TIMESTEP 812716 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  2.2929046 / Loss  0.03537118062376976
# fps: 2.6277186051421615
# TIMESTEP 812717 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4567533 / Loss  0.23319587111473083
# fps: 1.4779536934359863
# TIMESTEP 812718 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6590593 / Loss  0.023792535066604614
# fps: 2.9171354331847748
# TIMESTEP 812719 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5618663 / Loss  0.03146209567785263
# fps: 1.9428660895311936
# TIMESTEP 812720 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5004159 / Loss  0.2305288314819336
# fps: 2.65932035640172
# TIMESTEP 812721 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.734508 / Loss  0.11367051303386688
# fps: 1.9917581191264253
# TIMESTEP 812722 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2655504 / Loss  0.022797171026468277
# fps: 2.231842584024592
# TIMESTEP 812723 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4364142 / Loss  0.0069312648847699165
# fps: 2.252344142262223
# TIMESTEP 812724 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2557352 / Loss  0.015178853645920753
# fps: 2.1269117491947327
# TIMESTEP 812725 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.1392379 / Loss  0.062446821480989456
# fps: 2.4270303206352644
# TIMESTEP 812726 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8023721 / Loss  0.014727853238582611
# fps: 2.682533012783
# TIMESTEP 812727 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.7962319 / Loss  0.015171146020293236
# fps: 2.2558511267681385
# TIMESTEP 812728 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4448228 / Loss  0.03937847167253494
# fps: 2.3994530970666896
# TIMESTEP 812729 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6281375 / Loss  0.28565824031829834
# fps: 2.359128501876367
# TIMESTEP 812730 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5508751 / Loss  0.21624062955379486
# fps: 2.8052392774591217
# TIMESTEP 812731 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7668527 / Loss  0.04567530006170273
# fps: 2.787022215488846
# TIMESTEP 812732 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.618696 / Loss  0.0287691131234169
# fps: 2.4874562769617987
# TIMESTEP 812733 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6063209 / Loss  0.00600844994187355
# fps: 2.8264818242896736
# TIMESTEP 812734 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.6351625 / Loss  0.06357315927743912
# fps: 2.6261802553609264
# TIMESTEP 812735 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  0.64509636 / Loss  0.06264102458953857
# fps: 2.572575535561715
# TIMESTEP 812736 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4249868 / Loss  0.017753781750798225
# fps: 3.078442482656575
# TIMESTEP 812737 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8070812 / Loss  0.2649657428264618
# fps: 2.861236668654061
# TIMESTEP 812738 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7141728 / Loss  0.01351972483098507
# fps: 2.7946767731485274
# TIMESTEP 812739 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7123462 / Loss  0.017673015594482422
# fps: 2.6112593525990544
# TIMESTEP 812740 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7175667 / Loss  0.008968707174062729
# fps: 2.559381399515254
# TIMESTEP 812741 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6238239 / Loss  0.13238559663295746
# fps: 2.2098988283221686
# TIMESTEP 812742 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.579166 / Loss  0.020401274785399437
# fps: 2.8680864739931824
# TIMESTEP 812743 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.7203279 / Loss  0.031596653163433075
# fps: 2.932899234173002
# TIMESTEP 812744 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8159783 / Loss  0.01977231539785862
# fps: 3.027012359043753
# TIMESTEP 812745 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7822528 / Loss  0.024258557707071304
# fps: 2.820020560319122
# TIMESTEP 812746 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8553292 / Loss  0.271117240190506
# fps: 2.859826172808529
# TIMESTEP 812747 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3493838 / Loss  0.059952229261398315
# fps: 2.147882844914024
# TIMESTEP 812748 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.8585486 / Loss  0.1024036556482315
# fps: 0.8302060677845595
# TIMESTEP 812749 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7933182 / Loss  0.05312011018395424
# fps: 0.09191372149171863
# TIMESTEP 812750 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.8549858 / Loss  0.01751914620399475
# fps: 0.46328306034492756
# TIMESTEP 812751 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.414325 / Loss  0.009259204380214214
# fps: 1.0924350837420769
# TIMESTEP 812752 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.8507555 / Loss  0.27593547105789185
# fps: 0.45120123891697606
# TIMESTEP 812753 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4573703 / Loss  0.18968355655670166
# fps: 1.406282145333453
# TIMESTEP 812754 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.8723197 / Loss  0.16262805461883545
# fps: 0.5586505238933654
# TIMESTEP 812755 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  2.5812066 / Loss  0.2027372568845749
# fps: 0.5673176234441827
# TIMESTEP 812756 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8125945 / Loss  0.023992028087377548
# fps: 1.624927699057618
# TIMESTEP 812757 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.9327847 / Loss  0.02682187408208847
# fps: 1.174312255386844
# TIMESTEP 812758 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.4943454 / Loss  0.039758697152137756
# fps: 1.7341157374274352
# TIMESTEP 812759 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5756378 / Loss  0.18108688294887543
# fps: 1.4123686102444863
# TIMESTEP 812760 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9637897 / Loss  0.03681803494691849
# fps: 1.0535876530687347
# TIMESTEP 812761 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.472664 / Loss  0.03684893995523453
# fps: 1.5355533174370786
# TIMESTEP 812762 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.7189918 / Loss  0.010399355553090572
# fps: 1.180040474086428
# TIMESTEP 812763 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  2.0412445 / Loss  0.0197838693857193
# fps: 1.061895353417921
# TIMESTEP 812764 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6528785 / Loss  0.013692465610802174
# fps: 1.1416942996183195
# TIMESTEP 812765 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9879242 / Loss  0.31393682956695557
# fps: 0.999260734067485
# TIMESTEP 812766 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6971438 / Loss  0.06568176299333572
# fps: 1.2493715616101964
# TIMESTEP 812767 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8802812 / Loss  0.2801799178123474
# fps: 1.133344808270818
# TIMESTEP 812768 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.490706 / Loss  0.22432346642017365
# fps: 1.328210035777371
# TIMESTEP 812769 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD -1 / Q_MAX  2.2831478 / Loss  0.02905304916203022
# fps: 2.2399606940491004
# TIMESTEP 812770 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6991092 / Loss  0.4869098663330078
# fps: 1.9934213309138988
# TIMESTEP 812771 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.56881 / Loss  0.04887131601572037
# fps: 1.7689364544884036
# TIMESTEP 812772 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7556217 / Loss  0.05615421384572983
# fps: 2.2151029071514543
# TIMESTEP 812773 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7219834 / Loss  0.026632705703377724
# fps: 1.5811398837942647
# TIMESTEP 812774 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7851418 / Loss  0.011820130050182343
# fps: 1.2235022591145623
# TIMESTEP 812775 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  1.837493 / Loss  0.06081695854663849
# fps: 1.665005619085917
# TIMESTEP 812776 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6449805 / Loss  0.16997262835502625
# fps: 2.161545521869246
# TIMESTEP 812777 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD 0.1 / Q_MAX  2.5865355 / Loss  0.7320204973220825
# fps: 2.279532865503178
# TIMESTEP 812778 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 0 / REWARD -1 / Q_MAX  1.5275118 / Loss  0.016228999942541122
# fps: 2.162648903362794
# TIMESTEP 812779 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9749496 / Loss  0.17323735356330872
# fps: 1.2634884333216252
# TIMESTEP 812780 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5674903 / Loss  0.026469584554433823
# fps: 2.645644338643162
# TIMESTEP 812781 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7041875 / Loss  0.01499551348388195
# fps: 1.249617231908156
# TIMESTEP 812782 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4390512 / Loss  0.3126733899116516
# fps: 1.1027221381058059
# TIMESTEP 812783 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9163644 / Loss  0.022227635607123375
# fps: 0.7837532294309587
# TIMESTEP 812784 / STATE train / EPSILON 9.999999987391849e-05 / ACTION 1 / REWARD 0.1 / Q_MAX  2.3974595 / Loss  0.27469882369041443
# fps: 1.6685253556498005
# TIMESTEP
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-4829a0a02061> in <module>
# ----> 1 playGame(observe=False);
#
# <ipython-input-13-12216cee503d> in playGame(observe)
#       6     model = buildmodel()
#       7     try:
# ----> 8         trainNetwork(model,game_state,observe=observe)
#       9     except StopIteration:
#      10         game.end()
#
# <ipython-input-12-353d072bd202> in trainNetwork(model, game_state, observe)
#     129             state = "train"
#     130
# --> 131         print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)
#     132
#     133     print("Episode finished!")
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     406                     self.flush()
#     407             else:
# --> 408                 self._schedule_flush()
#     409
#     410     def writelines(self, sequence):
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in _schedule_flush(self)
#     330         def _schedule_in_thread():
#     331             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 332         self.pub_thread.schedule(_schedule_in_thread)
#     333
#     334     def flush(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
